# %% [markdown]
# # Notebook 01 — EDA (styles.csv)
#
# Objectif: comprendre le dataset et la cible MEN/WOMEN.

# %%
import pandas as pd

df = pd.read_csv('styles.csv', sep=';', on_bad_lines='skip')
df.columns = df.columns.str.strip()
df.head()

# %%
df['gender'].value_counts().head(10)

# %% [markdown]
# ## Colonnes utiles pour notre modèle
# On utilisera le texte produit (nom + catégorie + type) et on prédit `gender` (regroupé en MEN/WOMEN).

# %%
df[['productDisplayName','subCategory','articleType','gender']].isna().mean().sort_values(ascending=False).head(10)
