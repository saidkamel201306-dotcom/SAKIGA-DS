# %% [markdown]
# # Notebook 02 — Modélisation + GridSearchCV
#
# Ce notebook reprend exactement la logique de `train_gender_model.py`.

# %%
# !pip -q install -r requirements.txt

# %%
from train_gender_model import main
main()

# %% [markdown]
# ## Résultats
# Ouvre `reports/metrics.json` pour voir le modèle choisi + scores validation/test + matrice de confusion.

# %%
import json
from pathlib import Path
print(Path('reports/metrics.json').read_text(encoding='utf-8')[:1500])
